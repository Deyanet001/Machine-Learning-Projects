# %%
import pandas as pd
import numpy as np

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Out:
# --2025-01-06 19:03:55--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2025-01-06 19:03:56 (4.90 MB/s) - ‘car-sales.csv’ saved [369/369]

# %%
df = pd.read_csv('/content/car-sales.csv')
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
df.shape
# Out:
# (10, 5)

# %%
df.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
df[['Odometer (KM)', 'Make']]
# Out:
#    Odometer (KM)    Make
# 0         150043  Toyota
# 1          87899   Honda
# 2          32549  Toyota
# 3          11179     BMW
# 4         213095  Nissan
# 5          99213  Toyota
# 6          45698   Honda
# 7          54738   Honda
# 8          60000  Toyota
# 9          31600  Nissan

# %%
df[1:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
len(df['Make'])
# Out:
# 10

# %%
df[df['Odometer (KM)'] < 50000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df['Odometer (KM)'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Seats'] = 5
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00      5
# 1   Honda    Red          87899      4   $5,000.00      5
# 2  Toyota   Blue          32549      3   $7,000.00      5
# 3     BMW  Black          11179      5  $22,000.00      5
# 4  Nissan  White         213095      4   $3,500.00      5
# 5  Toyota  Green          99213      4   $4,500.00      5
# 6   Honda   Blue          45698      4   $7,500.00      5
# 7   Honda   Blue          54738      4   $7,000.00      5
# 8  Toyota  White          60000      4   $6,250.00      5
# 9  Nissan  White          31600      4   $9,700.00      5

# %%
df.isna()
# Out:
#     Make  Colour  Odometer (KM)  Doors  Price  Seats
# 0  False   False          False  False  False  False
# 1  False   False          False  False  False  False
# 2  False   False          False  False  False  False
# 3  False   False          False  False  False  False
# 4  False   False          False  False  False  False
# 5  False   False          False  False  False  False
# 6  False   False          False  False  False  False
# 7  False   False          False  False  False  False
# 8  False   False          False  False  False  False
# 9  False   False          False  False  False  False

# %%
df.notna().sum()
# Out:
# Make             10
# Colour           10
# Odometer (KM)    10
# Doors            10
# Price            10
# Seats            10
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.drop(['Make','Colour'], axis=1, inplace = True)

# %%
df
# Out:
#    Odometer (KM)  Doors       Price  Seats
# 0         150043      4   $4,000.00      5
# 1          87899      4   $5,000.00      5
# 2          32549      3   $7,000.00      5
# 3          11179      5  $22,000.00      5
# 4         213095      4   $3,500.00      5
# 5          99213      4   $4,500.00      5
# 6          45698      4   $7,500.00      5
# 7          54738      4   $7,000.00      5
# 8          60000      4   $6,250.00      5
# 9          31600      4   $9,700.00      5

# %%
df.columns
# Out:
# Index(['Odometer (KM)', 'Doors', 'Price', 'Seats'], dtype='object')

# %%
df['Price'].sum()
# Out:
# '$4,000.00$5,000.00$7,000.00$22,000.00$3,500.00$4,500.00$7,500.00$7,000.00$6,250.00$9,700.00'

# %%
df['Price'] = df['Price'].str.replace('$','').str.replace('.','').str.replace(',','')

# %%
df['Price'] = pd.to_numeric(df['Price']) / 100

# %%
df['Price'].sum()
# Out:
# 76450.0

# %%
df.loc[3]
# Out:
# Odometer (KM)    11179.0
# Doors                5.0
# Price            22000.0
# Seats                5.0
# Name: 3, dtype: float64

# %%
df.iloc[3]
# Out:
# Odometer (KM)    11179.0
# Doors                5.0
# Price            22000.0
# Seats                5.0
# Name: 3, dtype: float64
