# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot([2, 4, 6], [3, 6, 9])

# %%
plt.hist??

# %%
normal_dist = np.random.randn(1000)

# %%
sns.histplot(normal_dist, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
plt.hist([2, 3, 3, 1, 5, 6, 7])
# Out:
# (array([1., 1., 0., 2., 0., 0., 1., 0., 1., 1.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.rand(20)
y = np.random.rand(20)

plt.scatter(x, y)       #ya semicolon qoyursan ya da plt.show()

# %%
cars={"Bugatti" : 10,
      "Ferrari" : 7,
      "Tesla": 3}   #sol teref keys, sag teref values

# %%
plt.bar(cars.keys(), cars.values())
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(list(cars.keys()), list(cars.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/heart-disease.csv
# Out:
# --2025-01-23 14:33:10--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/heart-disease.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11328 (11K) [text/plain]
# Saving to: ‘heart-disease.csv’
#
# heart-disease.csv   100%[===================>]  11.06K  --.-KB/s    in 0s
#
# 2025-01-23 14:33:10 (60.6 MB/s) - ‘heart-disease.csv’ saved [11328/11328]

# %%
heart_diseases =  pd.read_csv("/content/heart-disease.csv")
heart_diseases
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_diseases['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (10, 7))
ax.plot([1, 2, 3], [4, 5, 6])

# %%
heart_diseases['trestbps'].plot(kind='hist', title = 'BPS DIST')
# Out:
# <Axes: title={'center': 'BPS DIST'}, ylabel='Frequency'>

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize = (10, 7))
ax1.plot(x,y)
ax2.hist(x)
ax3.pie(x)
ax4.bar(x, y)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.scatter(heart_diseases['age'], heart_diseases['chol'], c= 'purple')

# %%
plt.scatter(heart_diseases['age'], heart_diseases['chol'], c= heart_diseases['target'])

# %%
fig, ax = plt.subplots(figsize = (10, 7))
scatter  = ax.scatter(heart_diseases['age'], heart_diseases['chol'], c = heart_diseases['target'])
ax.legend(*scatter.legend_elements())
ax.set(title = 'Heart disease table', xlabel = 'Age', ylabel = 'Cholestrol')
ax.axhline(y = heart_diseases['chol'].mean(), c= 'red', linestyle = '-.')

# %%
fig.savefig
# Out:
# <bound method Figure.savefig of <Figure size 1000x700 with 1 Axes>>

# %%
sns.set_theme()
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip')

# %%
plt.subplots(figsize=(10, 30))
plt.hist(heart_diseases['age'], bins = 50)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  2.,  4.,  0.,  2.,  3.,  4.,  3., 10.,
#          8.,  8., 11.,  8.,  7.,  5.,  7.,  5.,  7., 12., 13.,  0.,  8.,
#         16.,  8., 11., 17., 19., 14., 11.,  8., 11.,  9., 10.,  8.,  7.,
#          9.,  4.,  3.,  4.,  3.,  0.,  0.,  1.,  0.,  1.,  1.]),
#  array([29.  , 29.96, 30.92, 31.88, 32.84, 33.8 , 34.76, 35.72, 36.68,
#         37.64, 38.6 , 39.56, 40.52, 41.48, 42.44, 43.4 , 44.36, 45.32,
#         46.28, 47.24, 48.2 , 49.16, 50.12, 51.08, 52.04, 53.  , 53.96,
#         54.92, 55.88, 56.84, 57.8 , 58.76, 59.72, 60.68, 61.64, 62.6 ,
#         63.56, 64.52, 65.48, 66.44, 67.4 , 68.36, 69.32, 70.28, 71.24,
#         72.2 , 73.16, 74.12, 75.08, 76.04, 77.  ]),
#  <BarContainer object of 50 artists>)
